# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

img = Image.open('dog.jpg')
imgGray = img.convert('LA')

plt.figure(figsize=(9,6))
plt.imshow(imgGray)

# %%
imgMat = np.array(list(imgGray.getdata(band=0)), float)
print(imgMat)
print(imgMat.shape)
# Out:
# [122. 124. 126. ... 224. 224. 224.]
# (16054528,)

# %%
print(imgGray.size[1])
print(imgGray.size[0])
# Out:
# 3472
# 4624

# %%
imgMat.shape = (imgGray.size[1], imgGray.size[0])
imgMat = np.matrix(imgMat)
plt.figure(figsize=(9,6))
plt.imshow(imgMat, cmap='bone')

# %%
u, s, v = np.linalg.svd(imgMat)
print(u.shape)
print()
print(s.shape)
print()
print(v.shape)

h,w,c = imgGray.shape
# Out:
# (3472, 3472)
#
# (3472,)
#
# (4624, 4624)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 8
#       5 print()
#       6 print(v.shape)
# ----> 8 h,w,c = imgGray.shape
#
# File c:\Users\karna\AppData\Local\Programs\Python\Python311\Lib\site-packages\PIL\Image.py:529, in Image.__getattr__(self, name)
#     527     deprecate("Image categories", 10, "is_animated", plural=True)
#     528     return self._category
# --> 529 raise AttributeError(name)
#
# AttributeError: shape

# %%
for i in range(5,101,10):
    reConstImg = np.matrix(u[:, :i]) * np.diag(s[:i]) * np.matrix(v[:i, :])
    plt.imshow(reConstImg, cmap='gray')
    title = "n = %s" % i
    print(reConstImg.shape)
    plt.title(title)
    plt.show()
    print()
# Out:
# (3472, 4624)
# (3472, 4624)
# (3472, 4624)
# (3472, 4624)
# (3472, 4624)
# (3472, 4624)
# (3472, 4624)
# (3472, 4624)
# (3472, 4624)
# (3472, 4624)
