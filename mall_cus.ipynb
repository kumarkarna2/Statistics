# %%
import pandas as pd 
import numpy as np 

data = pd.read_csv('dataset/Mall_Customers.csv')

data.isna().sum()

# %%
import matplotlib.pyplot as plt
import sklearn as sk
from sklearn.cluster import KMeans

x= data.iloc[:,[3,4]].values

# %%
wcss=[]

for i in range(1,11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)

wcss

# %%
plt.plot(range(1,11),wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.title('best value of k')
plt.show()

# %%
arr=np.array([1,1,2,1,4,3,5,4])
a = arr.reshape(4,2)

# %%
wess=[]
for i in range(1,5):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(a)
    wess.append(kmeans.inertia_)

wess
# Out:
# c:\Users\karna\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\karna\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\karna\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\karna\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [16.75, 1.5, 0.5, 0.0]

# %%
plt.plot(range(1,5),wess)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.title('best value of k')
plt.show()
